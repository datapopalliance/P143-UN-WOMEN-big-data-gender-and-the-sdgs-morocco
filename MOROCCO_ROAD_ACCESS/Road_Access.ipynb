# %%
import geopandas as gpd
import pandas as pd
import requests,zipfile,io
import os
from src.utils.functions import *
import folium
import rasterio
from rasterio.mask import mask
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from rasterstats import zonal_stats
from rasterio.features import shapes
from scipy.stats import linregress

# %% [markdown]
# ## Download and load Roads Data

# %%
continent_osm = 'africa'
country_full = 'morocco'
country_osm_url = 'https://download.geofabrik.de/%s/%s-latest-free.shp.zip'%(continent_osm,country_full)
data_path = 'Data/'

# %%
path_roads = os.path.join(data_path,'Roads','gis_osm_roads_free_1.shp')
        
# Download roads
download_and_extract_roads(country_osm_url, data_path, path_roads)
            
# Read and map roads in categories   
roads_shp_path = os.path.join(path_roads)
load_country = gpd.read_file(roads_shp_path)
uniq = load_country['fclass'].value_counts()
uniq = list(uniq[uniq > 20].index)
uniq.extend(['primary','secondary','trunk','motorway'])
uniq = list(set(uniq))
load_country = load_country[load_country['fclass'].isin(uniq)]
load_country_tot = map_roads(load_country)

# Create Morocco boundary map
morocco_shp = gpd.read_parquet(os.path.join(data_path,'boundaries_morocco.parquet'))

# Filter roads by category
load_country_tot = load_country_tot.to_crs(epsg=26192)
roads_primary_secondary = load_country_tot[load_country_tot.roads.isin(['primary','secondary'])]
roads_tertiary = load_country_tot[load_country_tot.roads.isin(['tertiary'])]

# Select primary, secondary and tertiary roads
roads_pst = load_country[load_country.roads.isin(['primary','secondary','tertiary'])]
roads_pst = roads_pst.rename({"roads":"type"},axis=1)

# %% [markdown]
# ## Case 1: Primary and Secondary roads

# %%
sample_points_ps = sample_points_within_roads(roads_primary_secondary)
sample_points_ps = gpd.sjoin(sample_points_ps,morocco_shp,predicate="within")
reachable_areas_ps = compute_isochrones(sample_points_ps,distance=2000,base_url='http://localhost:8080/ors')
missing_areas = morocco_shp.overlay(reachable_areas_ps, how='difference', keep_geom_type=None, make_valid=True)
result_ps = calculate_population(morocco_shp, missing_areas)
# Out:
# Processed 1000 points...
# Processed 2000 points...
# Processed 3000 points...
# Processed 4000 points...
# Processed 5000 points...
# Processed 6000 points...
# Processed 7000 points...
# Processed 8000 points...
# Processed 9000 points...
# Processed 10000 points...
# Processed 11000 points...
# Processed 12000 points...
# Processed 13000 points...
# Processed 14000 points...
# Processed 15000 points...
# Processed 16000 points...
# Processed 17000 points...
# Processed 18000 points...
# Processed 19000 points...
# Processed 20000 points...
# Processed 21000 points...
# Processed 22000 points...
# Processed 23000 points...
# Processed 24000 points...
# Processed 25000 points...
# Processed 26000 points...
# Processed 27000 points...
# Processed 28000 points...
# Processed 29000 points...
# Processed 30000 points...
# Processed 31000 points...
# Failed point 31944: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765898637287}})
# Failed point 31945: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765898637293}})
# Failed point 31946: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765898637298}})
# Processed 32000 points...

# %%
result_ps
# Out:
# {'pop_total': 38043584.3125, 'pop_excluded': 17392219.125}

# %% [markdown]
# #### Analyse de sensibilité sur les paramètres de simplification des routes

# %%
df_sensi = pd.DataFrame()
midpoint_spacings = [200,500,1000]
grid_cell_sizes = [200,500,1000]
i = 0
for midpoint_spacing in midpoint_spacings:
    for grid_cell_size in grid_cell_sizes:
        sample_points_ps = sample_points_within_roads(roads_primary_secondary,midpoint_spacing=midpoint_spacing,grid_cell_size=grid_cell_size)
        sample_points_ps = gpd.sjoin(sample_points_ps,morocco_shp,predicate="within")
        reachable_areas_ps = compute_isochrones(sample_points_ps,distance=2000,base_url='http://localhost:8080/ors')
        missing_areas = morocco_shp.overlay(reachable_areas_ps, how='difference', keep_geom_type=None, make_valid=True)
        result_ps = calculate_population(morocco_shp, missing_areas)
        df_sensi.loc[i,'grid_cell_size'] = grid_cell_size
        df_sensi.loc[i,'midpoint_spacing'] = midpoint_spacing
        df_sensi.loc[i,'pop_total'] = result_ps['pop_total']
        df_sensi.loc[i,'pop_excluded'] = result_ps['pop_excluded']
        i = i + 1
# Out:
# Processed 2000 points...
# Processed 3000 points...
# Processed 4000 points...
# Processed 5000 points...
# Processed 6000 points...
# Processed 7000 points...
# Processed 8000 points...
# Processed 9000 points...
# Processed 10000 points...
# Processed 11000 points...
# Failed point 11952: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765904878907}})
# Processed 12000 points...
# Processed 13000 points...
# Processed 14000 points...
# Processed 15000 points...
# Processed 16000 points...
# Processed 17000 points...
# Processed 18000 points...
# Processed 19000 points...
# Processed 20000 points...
# Processed 21000 points...
# Processed 22000 points...
# Processed 23000 points...
# Processed 24000 points...
# Processed 25000 points...
# Processed 26000 points...
# Processed 27000 points...
# Processed 28000 points...
# Processed 29000 points...
# Processed 30000 points...
# Processed 31000 points...
# Processed 32000 points...
# Processed 33000 points...
# Processed 34000 points...
# Processed 35000 points...
# Processed 36000 points...
# Processed 38000 points...
# Processed 39000 points...
# Processed 40000 points...
# Processed 41000 points...
# Processed 42000 points...
# Processed 43000 points...
# Processed 44000 points...
# Processed 45000 points...
# Processed 46000 points...
# Processed 47000 points...
# Processed 48000 points...
# Processed 49000 points...
# Processed 50000 points...
# Processed 52000 points...
# Processed 53000 points...
# Processed 54000 points...
# Processed 55000 points...
# Processed 56000 points...
# Processed 57000 points...
# Processed 58000 points...
# Processed 59000 points...
# Processed 60000 points...
# Processed 61000 points...
# Processed 62000 points...
# Processed 63000 points...
# Processed 64000 points...
# Processed 65000 points...
# Processed 66000 points...
# Processed 67000 points...
# Processed 68000 points...
# Processed 69000 points...
# Processed 70000 points...
# Processed 71000 points...
# Processed 72000 points...
# Processed 73000 points...
# Processed 74000 points...
# Processed 75000 points...
# Processed 76000 points...
# Processed 77000 points...
# Processed 78000 points...
# Processed 79000 points...
# Processed 80000 points...
# Processed 81000 points...
# Processed 82000 points...
# Processed 83000 points...
# Processed 84000 points...
# Processed 85000 points...
# Processed 86000 points...
# Processed 87000 points...
# Processed 88000 points...
# Processed 89000 points...
# Processed 90000 points...
# Processed 91000 points...
# Processed 92000 points...
# Processed 93000 points...
# Processed 95000 points...
# Processed 96000 points...
# Processed 97000 points...
# Processed 98000 points...
# Processed 99000 points...
# Processed 100000 points...
# Processed 101000 points...
# Processed 102000 points...
# Processed 103000 points...
# Processed 104000 points...
# Processed 105000 points...
# Processed 106000 points...
# Processed 107000 points...
# Processed 108000 points...
# Processed 109000 points...
# Processed 110000 points...
# Processed 111000 points...
# Processed 112000 points...
# Processed 113000 points...
# Processed 114000 points...
# Processed 115000 points...
# Processed 116000 points...
# Processed 117000 points...
# Processed 118000 points...
# Processed 119000 points...
# Processed 120000 points...
# Processed 121000 points...
# Processed 122000 points...
# Processed 123000 points...
# Processed 124000 points...
# Processed 125000 points...
# Processed 126000 points...
# Processed 127000 points...
# Processed 128000 points...
# Processed 129000 points...
# Failed point 129196: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905318182}})
# Failed point 129197: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905318184}})
# Failed point 129198: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905318186}})
# Processed 131000 points...
# Processed 132000 points...
# Processed 133000 points...
# Processed 134000 points...
# Processed 135000 points...
# Processed 136000 points...
# Processed 137000 points...
# Processed 138000 points...
# Processed 139000 points...
# Processed 140000 points...
# Processed 141000 points...
# Processed 142000 points...
# Processed 143000 points...
# Processed 144000 points...
# Processed 145000 points...
# Processed 146000 points...
# Processed 147000 points...
# Processed 148000 points...
# Processed 149000 points...
# Processed 150000 points...
# Processed 151000 points...
# Processed 152000 points...
# Processed 153000 points...
# Processed 154000 points...
# Processed 155000 points...
# Processed 156000 points...
# Processed 157000 points...
# Processed 158000 points...
# Processed 159000 points...
# Failed point 159586: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426156}})
# Failed point 159587: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426159}})
# Failed point 159588: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426160}})
# Failed point 159589: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426162}})
# Failed point 159590: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426164}})
# Failed point 159591: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426165}})
# Failed point 159592: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426167}})
# Failed point 159593: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426169}})
# Failed point 159594: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426170}})
# Failed point 159595: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426172}})
# Failed point 159596: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426173}})
# Failed point 159597: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426177}})
# Failed point 159598: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426178}})
# Failed point 159599: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426180}})
# Failed point 159600: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426182}})
# Failed point 159601: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426184}})
# Failed point 159602: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426185}})
# Failed point 159603: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426187}})
# Failed point 159604: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426188}})
# Failed point 159605: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905426189}})
# Processed 160000 points...
# Processed 161000 points...
# Processed 162000 points...
# Processed 163000 points...
# Processed 1000 points...
# Processed 2000 points...
# Processed 3000 points...
# Processed 4000 points...
# Processed 5000 points...
# Processed 6000 points...
# Processed 7000 points...
# Processed 8000 points...
# Failed point 8810: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765905680811}})
# Processed 9000 points...
# Processed 10000 points...
# Processed 11000 points...
# Processed 13000 points...
# Processed 14000 points...
# Processed 15000 points...
# Processed 16000 points...
# Processed 17000 points...
# Processed 18000 points...
# Processed 19000 points...
# Processed 20000 points...
# Processed 21000 points...
# Processed 22000 points...
# Processed 23000 points...
# Processed 24000 points...
# Processed 25000 points...
# Processed 26000 points...
# Processed 27000 points...
# Processed 28000 points...
# Processed 29000 points...
# Processed 30000 points...
# Processed 31000 points...
# Processed 32000 points...
# Processed 33000 points...
# Processed 34000 points...
# Processed 35000 points...
# Processed 36000 points...
# Processed 37000 points...
# Processed 38000 points...
# Processed 39000 points...
# Processed 40000 points...
# Processed 41000 points...
# Processed 42000 points...
# Processed 43000 points...
# Processed 44000 points...
# Processed 45000 points...
# Processed 46000 points...
# Processed 47000 points...
# Processed 48000 points...
# Processed 49000 points...
# Processed 50000 points...
# Processed 51000 points...
# Processed 52000 points...
# Processed 53000 points...
# Processed 54000 points...
# Processed 55000 points...
# Processed 56000 points...
# Processed 57000 points...
# Processed 58000 points...
# Processed 59000 points...
# Processed 60000 points...
# Processed 61000 points...
# Processed 62000 points...
# Processed 63000 points...
# Processed 64000 points...
# Processed 65000 points...
# Processed 66000 points...
# Processed 67000 points...
# Processed 68000 points...
# Processed 69000 points...
# Processed 70000 points...
# Processed 71000 points...
# Processed 72000 points...
# Processed 73000 points...
# Processed 74000 points...
# Processed 75000 points...
# Processed 76000 points...
# Processed 77000 points...
# Processed 78000 points...
# Processed 79000 points...
# Processed 80000 points...
# Processed 81000 points...
# Processed 82000 points...
# Processed 83000 points...
# Processed 84000 points...
# Processed 85000 points...
# Processed 86000 points...
# Processed 87000 points...
# Processed 88000 points...
# Processed 89000 points...
# Processed 90000 points...
# Processed 91000 points...
# Processed 92000 points...
# Processed 93000 points...
# Processed 94000 points...
# Processed 95000 points...
# Processed 96000 points...
# Processed 97000 points...
# Processed 98000 points...
# Processed 99000 points...
# Processed 100000 points...
# Processed 101000 points...
# Processed 102000 points...
# Processed 103000 points...
# Processed 104000 points...
# Processed 105000 points...
# Processed 106000 points...
# Processed 107000 points...
# Processed 108000 points...
# Processed 109000 points...
# Processed 110000 points...
# Processed 111000 points...
# Processed 112000 points...
# Processed 113000 points...
# Processed 114000 points...
# Processed 115000 points...
# Processed 116000 points...
# Processed 117000 points...
# Processed 118000 points...
# Processed 119000 points...
# Processed 120000 points...
# Processed 121000 points...
# Processed 122000 points...
# Processed 124000 points...
# Failed point 124880: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906116107}})
# Failed point 124881: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906116109}})
# Failed point 124882: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906116121}})
# Processed 125000 points...
# Processed 126000 points...
# Processed 127000 points...
# Processed 128000 points...
# Processed 129000 points...
# Processed 130000 points...
# Processed 131000 points...
# Processed 132000 points...
# Processed 133000 points...
# Processed 134000 points...
# Processed 135000 points...
# Processed 136000 points...
# Processed 137000 points...
# Processed 138000 points...
# Processed 139000 points...
# Processed 140000 points...
# Processed 141000 points...
# Processed 142000 points...
# Processed 143000 points...
# Processed 144000 points...
# Processed 145000 points...
# Processed 146000 points...
# Processed 147000 points...
# Processed 148000 points...
# Processed 149000 points...
# Processed 150000 points...
# Processed 151000 points...
# Processed 152000 points...
# Processed 153000 points...
# Processed 154000 points...
# Processed 155000 points...
# Failed point 155270: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229360}})
# Failed point 155271: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229363}})
# Failed point 155272: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229365}})
# Failed point 155273: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229368}})
# Failed point 155274: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229370}})
# Failed point 155275: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229372}})
# Failed point 155276: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229373}})
# Failed point 155277: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229375}})
# Failed point 155278: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229377}})
# Failed point 155279: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229380}})
# Failed point 155280: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229382}})
# Failed point 155281: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229384}})
# Failed point 155282: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229391}})
# Failed point 155283: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229394}})
# Failed point 155284: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229396}})
# Failed point 155285: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229398}})
# Failed point 155286: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229400}})
# Failed point 155287: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229403}})
# Failed point 155288: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229405}})
# Failed point 155289: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906229407}})
# Processed 156000 points...
# Processed 157000 points...
# Processed 158000 points...
# Processed 159000 points...
# Processed 1000 points...
# Processed 2000 points...
# Processed 3000 points...
# Processed 4000 points...
# Processed 5000 points...
# Processed 6000 points...
# Processed 7000 points...
# Processed 8000 points...
# Processed 9000 points...
# Processed 10000 points...
# Processed 11000 points...
# Processed 12000 points...
# Processed 13000 points...
# Processed 14000 points...
# Processed 15000 points...
# Processed 16000 points...
# Processed 17000 points...
# Processed 18000 points...
# Processed 19000 points...
# Processed 20000 points...
# Processed 21000 points...
# Processed 22000 points...
# Processed 23000 points...
# Processed 24000 points...
# Processed 25000 points...
# Processed 26000 points...
# Processed 27000 points...
# Processed 28000 points...
# Processed 29000 points...
# Processed 30000 points...
# Processed 31000 points...
# Processed 32000 points...
# Processed 33000 points...
# Processed 34000 points...
# Processed 35000 points...
# Processed 36000 points...
# Processed 37000 points...
# Processed 38000 points...
# Processed 39000 points...
# Processed 40000 points...
# Processed 41000 points...
# Processed 42000 points...
# Processed 43000 points...
# Processed 44000 points...
# Processed 45000 points...
# Processed 46000 points...
# Processed 47000 points...
# Processed 48000 points...
# Processed 49000 points...
# Processed 50000 points...
# Processed 51000 points...
# Processed 52000 points...
# Processed 53000 points...
# Processed 54000 points...
# Processed 55000 points...
# Processed 56000 points...
# Processed 57000 points...
# Processed 58000 points...
# Processed 59000 points...
# Processed 60000 points...
# Processed 61000 points...
# Processed 62000 points...
# Processed 63000 points...
# Processed 64000 points...
# Processed 65000 points...
# Processed 66000 points...
# Processed 67000 points...
# Processed 68000 points...
# Processed 69000 points...
# Processed 70000 points...
# Processed 72000 points...
# Processed 73000 points...
# Processed 74000 points...
# Processed 75000 points...
# Processed 76000 points...
# Processed 77000 points...
# Processed 78000 points...
# Processed 79000 points...
# Processed 80000 points...
# Processed 81000 points...
# Processed 82000 points...
# Processed 83000 points...
# Processed 84000 points...
# Processed 85000 points...
# Processed 86000 points...
# Processed 88000 points...
# Processed 89000 points...
# Processed 90000 points...
# Processed 91000 points...
# Processed 92000 points...
# Processed 93000 points...
# Processed 94000 points...
# Processed 95000 points...
# Processed 96000 points...
# Processed 97000 points...
# Processed 98000 points...
# Processed 99000 points...
# Processed 100000 points...
# Processed 101000 points...
# Processed 102000 points...
# Processed 103000 points...
# Processed 104000 points...
# Processed 105000 points...
# Processed 106000 points...
# Processed 107000 points...
# Processed 108000 points...
# Processed 109000 points...
# Processed 110000 points...
# Processed 111000 points...
# Processed 112000 points...
# Processed 113000 points...
# Processed 114000 points...
# Processed 115000 points...
# Processed 116000 points...
# Processed 117000 points...
# Processed 118000 points...
# Processed 119000 points...
# Processed 120000 points...
# Processed 121000 points...
# Processed 122000 points...
# Failed point 122075: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906791433}})
# Failed point 122076: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906791436}})
# Failed point 122077: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906791438}})
# Processed 124000 points...
# Processed 125000 points...
# Processed 126000 points...
# Processed 127000 points...
# Processed 128000 points...
# Processed 129000 points...
# Processed 130000 points...
# Processed 131000 points...
# Processed 132000 points...
# Processed 133000 points...
# Processed 134000 points...
# Processed 135000 points...
# Processed 136000 points...
# Processed 137000 points...
# Processed 138000 points...
# Processed 139000 points...
# Processed 140000 points...
# Processed 141000 points...
# Processed 142000 points...
# Processed 143000 points...
# Processed 144000 points...
# Processed 145000 points...
# Processed 146000 points...
# Processed 147000 points...
# Processed 148000 points...
# Processed 149000 points...
# Processed 150000 points...
# Processed 151000 points...
# Processed 152000 points...
# Failed point 152465: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896557}})
# Failed point 152466: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896574}})
# Failed point 152467: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896577}})
# Failed point 152468: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896579}})
# Failed point 152469: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896580}})
# Failed point 152470: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896582}})
# Failed point 152471: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896583}})
# Failed point 152472: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896585}})
# Failed point 152473: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896586}})
# Failed point 152474: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896588}})
# Failed point 152475: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896589}})
# Failed point 152476: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896591}})
# Failed point 152477: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896592}})
# Failed point 152478: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896594}})
# Failed point 152479: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896595}})
# Failed point 152480: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896596}})
# Failed point 152481: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896598}})
# Failed point 152482: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896599}})
# Failed point 152483: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896600}})
# Failed point 152484: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765906896602}})
# Processed 153000 points...
# Processed 154000 points...
# Processed 155000 points...
# Processed 156000 points...
# Processed 2000 points...
# Processed 3000 points...
# Processed 4000 points...
# Processed 5000 points...
# Processed 6000 points...
# Processed 7000 points...
# Processed 8000 points...
# Processed 9000 points...
# Processed 10000 points...
# Processed 11000 points...
# Failed point 11952: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765907777096}})
# Processed 12000 points...
# Processed 13000 points...
# Processed 14000 points...
# Processed 15000 points...
# Processed 16000 points...
# Processed 17000 points...
# Processed 18000 points...
# Processed 19000 points...
# Processed 20000 points...
# Processed 21000 points...
# Processed 22000 points...
# Processed 23000 points...
# Processed 24000 points...
# Processed 25000 points...
# Processed 26000 points...
# Processed 27000 points...
# Processed 28000 points...
# Processed 29000 points...
# Processed 30000 points...
# Processed 31000 points...
# Processed 32000 points...
# Processed 33000 points...
# Processed 34000 points...
# Processed 35000 points...
# Processed 36000 points...
# Processed 37000 points...
# Processed 38000 points...
# Processed 39000 points...
# Processed 40000 points...
# Processed 41000 points...
# Processed 42000 points...
# Processed 43000 points...
# Processed 44000 points...
# Processed 45000 points...
# Processed 46000 points...
# Processed 47000 points...
# Processed 48000 points...
# Processed 49000 points...
# Processed 50000 points...
# Processed 51000 points...
# Processed 52000 points...
# Processed 53000 points...
# Processed 54000 points...
# Processed 55000 points...
# Processed 56000 points...
# Processed 57000 points...
# Failed point 57507: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765907944603}})
# Processed 58000 points...
# Processed 59000 points...
# Processed 60000 points...
# Processed 61000 points...
# Processed 62000 points...
# Processed 63000 points...
# Processed 64000 points...
# Processed 65000 points...
# Processed 66000 points...
# Processed 67000 points...
# Processed 68000 points...
# Failed point 68522: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765907987756}})
# Failed point 68523: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765907987759}})
# Failed point 68524: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765907987761}})
# Failed point 68525: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765907987764}})
# Failed point 68526: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765907987766}})
# Failed point 68527: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765907987768}})
# Failed point 68528: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765907987769}})
# Processed 69000 points...
# Processed 1000 points...
# Processed 2000 points...
# Processed 3000 points...
# Processed 4000 points...
# Processed 5000 points...
# Processed 6000 points...
# Processed 7000 points...
# Processed 8000 points...
# Failed point 8810: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908216972}})
# Processed 9000 points...
# Processed 10000 points...
# Processed 11000 points...
# Processed 12000 points...
# Processed 13000 points...
# Processed 14000 points...
# Processed 15000 points...
# Processed 16000 points...
# Processed 17000 points...
# Processed 18000 points...
# Processed 19000 points...
# Processed 20000 points...
# Processed 21000 points...
# Processed 22000 points...
# Processed 23000 points...
# Processed 24000 points...
# Processed 25000 points...
# Processed 26000 points...
# Processed 27000 points...
# Processed 28000 points...
# Processed 29000 points...
# Processed 30000 points...
# Processed 31000 points...
# Processed 32000 points...
# Processed 33000 points...
# Processed 34000 points...
# Processed 35000 points...
# Processed 36000 points...
# Processed 37000 points...
# Processed 38000 points...
# Processed 39000 points...
# Processed 40000 points...
# Processed 41000 points...
# Processed 42000 points...
# Processed 43000 points...
# Processed 44000 points...
# Processed 45000 points...
# Processed 46000 points...
# Processed 47000 points...
# Processed 48000 points...
# Processed 49000 points...
# Processed 50000 points...
# Processed 51000 points...
# Processed 52000 points...
# Processed 53000 points...
# Failed point 53191: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908389801}})
# Processed 54000 points...
# Processed 55000 points...
# Processed 56000 points...
# Processed 57000 points...
# Processed 58000 points...
# Processed 59000 points...
# Processed 60000 points...
# Processed 61000 points...
# Processed 62000 points...
# Processed 63000 points...
# Processed 64000 points...
# Failed point 64206: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908429575}})
# Failed point 64207: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908429577}})
# Failed point 64208: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908429579}})
# Failed point 64209: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908429580}})
# Failed point 64210: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908429582}})
# Failed point 64211: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908429583}})
# Failed point 64212: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908429585}})
# Processed 65000 points...
# Processed 1000 points...
# Processed 2000 points...
# Processed 3000 points...
# Processed 4000 points...
# Processed 5000 points...
# Processed 6000 points...
# Processed 7000 points...
# Processed 8000 points...
# Processed 9000 points...
# Processed 10000 points...
# Processed 11000 points...
# Processed 12000 points...
# Processed 13000 points...
# Processed 14000 points...
# Processed 15000 points...
# Processed 16000 points...
# Processed 17000 points...
# Processed 18000 points...
# Processed 19000 points...
# Processed 20000 points...
# Processed 21000 points...
# Processed 22000 points...
# Processed 23000 points...
# Processed 24000 points...
# Processed 25000 points...
# Processed 26000 points...
# Processed 27000 points...
# Processed 28000 points...
# Processed 29000 points...
# Processed 30000 points...
# Processed 31000 points...
# Processed 32000 points...
# Processed 33000 points...
# Processed 34000 points...
# Processed 35000 points...
# Processed 36000 points...
# Processed 37000 points...
# Processed 38000 points...
# Processed 39000 points...
# Processed 40000 points...
# Processed 41000 points...
# Processed 42000 points...
# Processed 43000 points...
# Processed 44000 points...
# Processed 45000 points...
# Processed 46000 points...
# Processed 47000 points...
# Processed 48000 points...
# Processed 49000 points...
# Processed 50000 points...
# Failed point 50386: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908699656}})
# Processed 51000 points...
# Processed 52000 points...
# Processed 53000 points...
# Processed 54000 points...
# Processed 55000 points...
# Processed 56000 points...
# Processed 57000 points...
# Processed 58000 points...
# Processed 59000 points...
# Processed 60000 points...
# Processed 61000 points...
# Failed point 61401: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908737436}})
# Failed point 61402: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908737438}})
# Failed point 61403: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908737439}})
# Failed point 61404: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908737441}})
# Failed point 61405: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908737442}})
# Failed point 61406: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908737444}})
# Failed point 61407: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765908737446}})
# Processed 62000 points...
# Processed 2000 points...
# Processed 3000 points...
# Processed 4000 points...
# Processed 5000 points...
# Processed 6000 points...
# Processed 7000 points...
# Processed 8000 points...
# Processed 9000 points...
# Processed 10000 points...
# Processed 11000 points...
# Failed point 11952: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765909576915}})
# Processed 12000 points...
# Processed 13000 points...
# Processed 14000 points...
# Processed 15000 points...
# Processed 16000 points...
# Processed 17000 points...
# Processed 18000 points...
# Processed 19000 points...
# Processed 20000 points...
# Processed 21000 points...
# Processed 22000 points...
# Processed 23000 points...
# Processed 24000 points...
# Processed 25000 points...
# Processed 26000 points...
# Processed 27000 points...
# Processed 28000 points...
# Processed 29000 points...
# Processed 30000 points...
# Processed 31000 points...
# Processed 32000 points...
# Processed 33000 points...
# Processed 34000 points...
# Processed 35000 points...
# Processed 36000 points...
# Processed 37000 points...
# Processed 38000 points...
# Processed 39000 points...
# Failed point 39065: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765909677605}})
# Failed point 39066: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765909677607}})
# Failed point 39067: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765909677621}})
# Processed 1000 points...
# Processed 2000 points...
# Processed 3000 points...
# Processed 4000 points...
# Processed 5000 points...
# Processed 6000 points...
# Processed 7000 points...
# Processed 8000 points...
# Failed point 8810: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765909876127}})
# Processed 9000 points...
# Processed 10000 points...
# Processed 11000 points...
# Processed 12000 points...
# Processed 13000 points...
# Processed 14000 points...
# Processed 15000 points...
# Processed 16000 points...
# Processed 17000 points...
# Processed 18000 points...
# Processed 19000 points...
# Processed 20000 points...
# Processed 21000 points...
# Processed 22000 points...
# Processed 23000 points...
# Processed 24000 points...
# Processed 25000 points...
# Processed 26000 points...
# Processed 27000 points...
# Processed 28000 points...
# Processed 29000 points...
# Processed 30000 points...
# Processed 31000 points...
# Processed 32000 points...
# Processed 33000 points...
# Processed 34000 points...
# Failed point 34749: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765909964144}})
# Failed point 34750: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765909964146}})
# Failed point 34751: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765909964147}})
# Processed 35000 points...
# Processed 1000 points...
# Processed 2000 points...
# Processed 3000 points...
# Processed 4000 points...
# Processed 5000 points...
# Processed 6000 points...
# Processed 7000 points...
# Processed 8000 points...
# Processed 9000 points...
# Processed 10000 points...
# Processed 11000 points...
# Processed 12000 points...
# Processed 13000 points...
# Processed 14000 points...
# Processed 15000 points...
# Processed 16000 points...
# Processed 17000 points...
# Processed 18000 points...
# Processed 19000 points...
# Processed 20000 points...
# Processed 21000 points...
# Processed 22000 points...
# Processed 23000 points...
# Processed 24000 points...
# Processed 25000 points...
# Processed 26000 points...
# Processed 27000 points...
# Processed 28000 points...
# Processed 29000 points...
# Processed 30000 points...
# Processed 31000 points...
# Failed point 31944: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765910141836}})
# Failed point 31945: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765910141838}})
# Failed point 31946: 500 ({'error': {'code': 3099, 'message': 'Unable to build an isochrone map.'}, 'info': {'engine': {'build_date': '2025-09-30T14:28:56Z', 'graph_version': '3', 'graph_date': '2025-12-16T15:11:07Z', 'osm_date': '2025-10-23T20:20:52Z', 'version': '9.4.0'}, 'timestamp': 1765910141840}})
# Processed 32000 points...

# %%
df_sensi['share_excluded'] = df_sensi['pop_excluded'] / df_sensi['pop_total']

# %%
df_sensi
# Out:
#    grid_cell_size  midpoint_spacing     pop_total  pop_excluded  \
# 0           200.0             200.0  3.804358e+07  1.666596e+07
# 1           500.0             200.0  3.804358e+07  1.668549e+07
# 2          1000.0             200.0  3.804358e+07  1.670379e+07
# 3           200.0             500.0  3.804358e+07  1.690161e+07
# 4           500.0             500.0  3.804358e+07  1.694032e+07
# 5          1000.0             500.0  3.804358e+07  1.700139e+07
# 6           200.0            1000.0  3.804358e+07  1.719902e+07
# 7           500.0            1000.0  3.804358e+07  1.726077e+07
# 8          1000.0            1000.0  3.804358e+07  1.739222e+07
#
#    share_excluded
# 0        0.438076
# 1        0.438589
# 2        0.439070
# 3        0.444270
# 4        0.445287
# 5        0.446892
# 6        0.452087
# 7        0.453710
# 8        0.457166

# %% [markdown]
# ## Case 2 : Tertiary Roads

# %%
sample_points_t = sample_points_within_roads(roads_tertiary)
sample_points_t = gpd.sjoin(sample_points_t,morocco_shp,predicate="within")
reachable_areas_t = compute_isochrones(sample_points_t,distance=2000,base_url='http://localhost:8080/ors')

reachable_areas_pst = pd.concat([reachable_areas_ps,reachable_areas_t]).dissolve()
missing_areas_pst = morocco_shp.overlay(reachable_areas_pst, how='difference', keep_geom_type=None, make_valid=True)
result_pst = calculate_population(morocco_shp, missing_areas_pst)

# %%
reachable_areas_pst = pd.concat([reachable_areas_ps,reachable_areas_t]).dissolve()
missing_areas_pst = morocco_shp.overlay(reachable_areas_pst, how='difference', keep_geom_type=None, make_valid=True)
result_pst = calculate_population(morocco_shp, missing_areas_pst)

# %%
result_pst

# %% [markdown]
# ## Communes enclavées

# %%
# Find pixels outside of roads
missing_areas_pst = morocco_shp.overlay(reachable_areas_pst, how='difference', keep_geom_type=None, make_valid=True)
pop_path = os.path.join(data_path,'pop_morocco.tif')
if not os.path.exists(pop_path):
    create_population_map(pop_path)
pop_raster = rasterio.open(pop_path)
outside_mask, _ = mask(pop_raster, missing_areas_pst.geometry, crop=False, invert=False)
outside_mask = outside_mask[0]
outside_mask[outside_mask==-99999] = np.nan
profile = pop_raster.profile
profile.update(dtype=rasterio.float32, nodata=np.nan)

with rasterio.open('Data/pop_enclavee.tif', 'w', **profile) as dst:
    dst.write(outside_mask.astype(rasterio.float32), 1)

# %%
communes_shp = gpd.read_parquet(os.path.join(data_path,'communes_poverty.parquet'))
communes_shp = communes_shp.to_crs(epsg=4326)
communes_shp['Pop_WP'] = [0 if pd.isna(item['sum']) else item['sum'] for item in zonal_stats(communes_shp, pop_path, stats="sum",all_touched=True)]
communes_shp['Pop_enclavée'] = [0 if pd.isna(item['sum']) else item['sum'] for item in zonal_stats(communes_shp, os.path.join(data_path,'pop_enclavee.tif'), stats="sum",all_touched=True)]
communes_shp['Share_enclavée'] = communes_shp.Pop_enclavée/communes_shp.Pop_WP
communes_shp.to_parquet(os.path.join(data_path,'communes_enclavees.parquet'))

# %% [markdown]
# ## Save plots

# %%
communes_shp = gpd.read_parquet(os.path.join(data_path,'communes_enclavees.parquet'))
viz_communes = create_map(communes_shp,0.5,"Commune",0.4)
viz_communes.save('output/enclavement_commune_50.html')
create_map(communes_shp,0.1,"Commune",0.2).save('output/enclavement_commune_10.html')
create_map(communes_shp,0.3,"Commune",0.2).save('output/enclavement_commune_30.html')

# %% [markdown]
# ## Enclavement sur carreaux de 100km²

# %%
# Downsample population raster by a factor of 100
input_path_tot = os.path.join(data_path,"pop_morocco.tif")
output_path_tot = os.path.join(data_path,"pop_morocco_10km.tif")

downsample_raster(100,input_path_tot,output_path_tot)

# Downsample population enclavée raster by a factor of 100

input_path_enc = os.path.join(data_path,"pop_enclavee.tif")
output_path_enc = os.path.join(data_path,"pop_enclavee_10km.tif")

downsample_raster(100,input_path_enc,output_path_enc)

# Calculer le taux d'enclavement par pixel
ratio_enclavement_path = os.path.join(data_path,'Ratio_enclavement.tif')
compute_ratio_rasters(output_path_enc,output_path_tot,ratio_enclavement_path)

# %%
# Transform raster to vector for visualizations
with rasterio.open(ratio_enclavement_path) as src:
    image = src.read(1)  # read first band
    transform = src.transform

    # --- Correct mask: keep only finite (non-NaN) pixels
    mask = (image != src.nodata) & np.isfinite(image)

    # --- Polygonize raster
    results = (
        {'properties': {'Share_enclavée': float(v)}, 'geometry': s}
        for s, v in shapes(image, mask=mask, transform=transform)
    )
geoms = list(results)
gdf = gpd.GeoDataFrame.from_features(geoms, crs=src.crs)
gdf = gdf[~pd.isna(gdf.Share_enclavée)]
gdf['id'] = gdf.index

viz_carreaux = create_map(gdf,0.5,"id",0.2)
viz_carreaux.save('output/enclavement_carreaux_50.html')
create_map(gdf,0.1,"id",0.2).save('output/enclavement_carreaux_10.html')
create_map(gdf,0.3,"id",0.2).save('output/enclavement_carreaux_30.html')
create_map(gdf,0.5,"id",0.2).save('output/enclavement_carreaux_50.html')

# %% [markdown]
# ### Analyse multivariée

# %% [markdown]
# #### Pauvreté Multidimensionnelle

# %%
communes_shp = gpd.read_parquet(os.path.join(data_path,'communes_enclavees.parquet'))
communes_shp = communes_shp[['Share_enclavée','Multi_Pove']].dropna()

x = communes_shp['Share_enclavée']
y = communes_shp['Multi_Pove']
result = linregress(x, y)

slope = result.slope
intercept = result.intercept
p_value = result.pvalue
r_squared = result.rvalue ** 2

# Regression line
x_vals = np.linspace(x.min(), x.max(), 100)
y_vals = intercept + slope * x_vals

# Plot
plt.figure()
plt.scatter(x, y)
plt.plot(x_vals, y_vals,'red')
plt.xlabel('Part de la population enclavée')
plt.ylabel('Pauveté Multidimensionnelle')
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
plt.gca().xaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))

# Annotation
equation_text = (
    f"y = {slope:.1f}x + {intercept:.2f}\n"
    f"p-value = {p_value:.1e}\n"
    f"R² = {100*r_squared:.0f}%"
)

plt.text(
    0.05, 0.95,
    equation_text,
    transform=plt.gca().transAxes,
    verticalalignment='top'
)

plt.show()

# %% [markdown]
# #### Taux de chômage féminin

# %%
communes_shp = gpd.read_parquet(os.path.join(data_path,'communes_enclavees.parquet'))
communes_shp = communes_shp[['Share_enclavée','Women_unemp']].dropna()
communes_shp = communes_shp[communes_shp.Women_unemp>5]
x = communes_shp['Share_enclavée']
y = communes_shp['Women_unemp']/100
result = linregress(x, y)

slope = result.slope
intercept = result.intercept
p_value = result.pvalue
r_squared = result.rvalue ** 2

# Regression line
x_vals = np.linspace(x.min(), x.max(), 100)
y_vals = intercept + slope * x_vals

# Plot
plt.figure()
plt.scatter(x, y)
plt.plot(x_vals, y_vals,'red')
plt.xlabel('Part de la population enclavée')
plt.ylabel('Taux de chômage féminin')
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
plt.gca().xaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
# Annotation
equation_text = (
    f"y = {slope:.2f}x + {intercept:.1f}\n"
    f"p-value = {p_value:.3e}\n"
    f"R² = {100*r_squared:.0f}%"
)

plt.text(
    0.70, 0.98,
    equation_text,
    transform=plt.gca().transAxes,
    verticalalignment='top'
)

plt.show()
